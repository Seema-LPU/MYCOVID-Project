# %%
import pandas as pd
file1=pd.read_csv("agedetails.csv",delimiter=",")
file1
# Out:
#    Sno AgeGroup  TotalCases Percentage
# 0    1      0-9          22      3.18%
# 1    2    10-19          27      3.90%
# 2    3    20-29         172     24.86%
# 3    4    30-39         146     21.10%
# 4    5    40-49         112     16.18%
# 5    6    50-59          77     11.13%
# 6    7    60-69          89     12.86%
# 7    8    70-79          28      4.05%
# 8    9     >=80          10      1.45%
# 9   10  Missing           9      1.30%

# %%
file2=pd.read_csv("covid_19_india.csv",delimiter=",")
file2.tail()
# Out:
#        Sno      Date     Time              State/UnionTerritory  \
# 3778  3779  05/07/20  8:00 AM                           Tripura
# 3779  3780  05/07/20  8:00 AM                       Uttarakhand
# 3780  3781  05/07/20  8:00 AM                     Uttar Pradesh
# 3781  3782  05/07/20  8:00 AM                       West Bengal
# 3782  3783  05/07/20  8:00 AM  Cases being reassigned to states
#
#      ConfirmedIndianNational ConfirmedForeignNational  Cured  Deaths  \
# 3778                       -                        -   1202       1
# 3779                       -                        -   2502      42
# 3780                       -                        -  18154     773
# 3781                       -                        -  14166     736
# 3782                       -                        -      0       0
#
#       Confirmed
# 3778       1546
# 3779       3093
# 3780      26554
# 3781      21231
# 3782       4629

# %%
file3=pd.read_csv("HospitalBedsIndia.csv",delimiter=",")
file3
# Out:
#     Sno                   State/UT NumPrimaryHealthCenters_HMIS  \
# 0     1  Andaman & Nicobar Islands                           27
# 1     2             Andhra Pradesh                         1417
# 2     3          Arunachal Pradesh                          122
# 3     4                      Assam                         1007
# 4     5                      Bihar                         2007
# 5     6                 Chandigarh                           40
# 6     7               Chhattisgarh                          813
# 7     8       Dadra & Nagar Haveli                            9
# 8     9                Daman & Diu                            4
# 9    10                      Delhi                          534
# 10   11                        Goa                           31
# 11   12                    Gujarat                         1770
# 12   13                    Haryana                          500
# 13   14           Himachal Pradesh                          516
# ...

# %%
file4=pd.read_csv("ICMRTestingLabs.csv",delimiter=",")
file4.isnull().tail(20)
# Out:
#        lab  address  pincode   city  state   type
# 247  False    False    False  False  False  False
# 248  False    False    False  False  False  False
# 249  False    False    False  False  False  False
# 250  False    False    False  False  False  False
# 251  False    False    False  False  False  False
# 252  False    False    False  False  False  False
# 253  False    False    False  False  False  False
# 254  False    False    False  False  False  False
# 255  False    False    False  False  False  False
# 256  False    False    False  False  False  False
# 257  False    False    False  False  False  False
# 258  False    False    False  False  False  False
# 259  False    False    False  False  False  False
# 260  False    False    False  False  False  False
# 261  False    False    False  False  False  False
# 262  False    False    False  False  False  False
# 263  False    False    False  False  False  False
# 264  False    False    False  False  False  False
# ...

# %%
file5=pd.read_csv("IndividualDetails.csv",delimiter=",")
file5.describe()
# Out:
#                  id
# count  28182.000000
# mean   14091.344759
# std     8135.814132
# min        0.000000
# 25%     7046.250000
# 50%    14091.500000
# 75%    21136.750000
# max    28182.000000

# %%
file6=pd.read_csv("population_india_census2011.csv",delimiter=",")
file6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Sno                      36 non-null     int64
#  1   State / Union Territory  36 non-null     object
#  2   Population               36 non-null     int64
#  3   Rural population         36 non-null     int64
#  4   Urban population         36 non-null     int64
#  5   Area                     36 non-null     object
#  6   Density                  36 non-null     object
#  7   Gender Ratio             36 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 2.4+ KB

# %%
file7=pd.read_csv("StatewiseTestingDetails.csv",delimiter=",")
file7.head()
# Out:
#          Date                        State  TotalSamples Negative  Positive
# 0  2020-04-17  Andaman and Nicobar Islands        1403.0     1210      12.0
# 1  2020-04-24  Andaman and Nicobar Islands        2679.0      NaN      27.0
# 2  2020-04-27  Andaman and Nicobar Islands        2848.0      NaN      33.0
# 3  2020-05-01  Andaman and Nicobar Islands        3754.0      NaN      33.0
# 4  2020-05-16  Andaman and Nicobar Islands        6677.0      NaN      33.0
